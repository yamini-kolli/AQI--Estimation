# %%
import pandas as pd

# %%
df1 = pd.read_csv('cites_data/Ahmedabad.csv')
df2 = pd.read_csv("cites_data/Bengaluru.csv")
df3 = pd.read_csv('cites_data/Chennai.csv')
df4 = pd.read_csv("cites_data/Delhi.csv")
df5 = pd.read_csv('cites_data/Hyderabad.csv')
df6 = pd.read_csv("cites_data/Kolkata.csv")
df7 = pd.read_csv("cites_data/Mumbai.csv")
df8 = pd.read_csv("cites_data/Pune.csv")
df9 = pd.read_csv("cites_data/Visakhapatnam.csv")

# %%
df9 = df9.drop(['Unnamed: 0'],axis=1)
df9
# Out:
#     aqi     co       datetime    no2    o3   pm10   pm25   so2  \
# 0   100   84.0  2025-03-04:09    4.0  99.0   40.0  35.00   6.0
# 1    98  504.0  2025-03-04:08  141.0   5.8   98.0  34.00  23.0
# 2   150  675.0  2025-03-04:07  139.0   6.1  128.0  54.00  13.0
# 3   171  338.0  2025-03-04:06  113.5   9.9  125.0  71.50  11.5
# 4   171  474.0  2025-03-04:05  133.0   7.8  156.0  71.33  13.0
# ..  ...    ...            ...    ...   ...    ...    ...   ...
# 67  119  187.0  2025-03-01:14  127.5   7.8   72.5  42.50  19.0
# 68  104  302.0  2025-03-01:13  127.0   5.8   78.0  37.00  18.0
# 69  153    0.0  2025-03-01:12   67.0  12.9   73.0  55.00  17.0
# 70  121  302.0  2025-03-01:11  133.0   6.6   92.0  43.00  17.0
# 71  161  216.5  2025-03-01:10   99.0  13.5  120.5  64.00  19.5
#
#         timestamp_local        timestamp_utc          ts city_name
# 0   2025-03-04T14:30:00  2025-03-04T09:00:00  1741078800  Gajuwaka
# 1   2025-03-04T13:30:00  2025-03-04T08:00:00  1741075200  Gajuwaka
# ...

# %%
datasets = [df1,df2,df3,df4,df5,df6,df7,df8,df9]
for i in range(len(datasets)):
    print(f"columns in df{i+1} : {len(datasets[i].columns.to_list())}")
# Out:
# columns in df1 : 12
# columns in df2 : 12
# columns in df3 : 12
# columns in df4 : 12
# columns in df5 : 12
# columns in df6 : 12
# columns in df7 : 12
# columns in df8 : 12
# columns in df9 : 12

# %%
datasets = [df1,df2,df3,df4,df5,df6,df7,df8,df9]
combined_data = pd.concat(datasets,ignore_index=True)
combined_data
# Out:
#      aqi     co       datetime    no2    o3   pm10    pm25   so2  \
# 0    128  215.4  2025-03-04:11   25.7  92.1   99.7   45.67  29.2
# 1    211  614.5  2025-03-04:10   81.5  37.8  209.0  101.00  39.0
# 2    208  534.0  2025-03-04:09   71.0  34.2  201.0   99.00  37.5
# 3    206   91.0  2025-03-04:08   40.2  42.0  141.8   97.91  25.5
# 4    227  121.0  2025-03-04:07   56.0  61.1  170.8  113.25  45.3
# ..   ...    ...            ...    ...   ...    ...     ...   ...
# 643  119  187.0  2025-03-01:14  127.5   7.8   72.5   42.50  19.0
# 644  104  302.0  2025-03-01:13  127.0   5.8   78.0   37.00  18.0
# 645  153    0.0  2025-03-01:12   67.0  12.9   73.0   55.00  17.0
# 646  121  302.0  2025-03-01:11  133.0   6.6   92.0   43.00  17.0
# 647  161  216.5  2025-03-01:10   99.0  13.5  120.5   64.00  19.5
#
#          timestamp_local        timestamp_utc          ts  city_name
# 0    2025-03-04T16:30:00  2025-03-04T11:00:00  1741086000  Ahmedabad
# ...

# %%
combined_data.to_csv("datasets/raw_dataset.csv",index=False)
