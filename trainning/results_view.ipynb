# %%
import pandas as pd

# %%
train_res = pd.read_csv('results/results_train.csv')
test_res = pd.read_csv('results/results_test.csv')

# %%
train_res
# Out:
#                      Model  Mean_absolute_error  Mean_squared_error  \
# 0         base_model(mean)                36.23             2428.07
# 1        Linear Regression                10.37              315.43
# 2    DecisionTreeRegressor                11.41              312.88
# 3  Random Forest Regressor                 1.26               61.57
# 4         Gradient Bosting                 0.82                1.66
# 5  Ensembled_stacked_model                 2.01               43.09
#
#    Root_Mean_Squared_error  R2_score
# 0                    49.28      0.00
# 1                    17.76      0.87
# 2                    17.69      0.87
# 3                     7.85      0.97
# 4                     1.29      1.00
# 5                     6.56      0.98

# %%
test_res
# Out:
#                      Model  Mean_absolute_error  Mean_squared_error  \
# 0         base_model(mean)                36.23             2428.07
# 1        Linear Regression                12.65              624.17
# 2    DecisionTreeRegressor                15.70             1948.59
# 3  Random Forest Regressor                 5.13             1153.17
# 4         Gradient Bosting                 3.45              330.03
# 5  Ensembled_stacked_model                 3.45               68.56
#
#    Root_Mean_Squared_error  R2_score
# 0                    49.28      0.00
# 1                    24.98      0.81
# 2                    44.14      0.39
# 3                    33.96      0.64
# 4                    18.17      0.90
# 5                     8.28      0.98
